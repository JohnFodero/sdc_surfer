# %%
# based on https://wroscoe.github.io/keras-lane-following-autopilot.html
# %load_ext autoreload
# %autoreload 2
import os
import urllib.request
import pickle
import numpy as np
import cv2
from tools import *

# %matplotlib inline
import matplotlib
from matplotlib.pyplot import imshow, imread

# %% [markdown]
# # Get Data

# %%
raw_X, raw_y = import_data('../inloop3')
print('Images loaded.')
print('Processing images..')
raw_X = np.array([process_image(item) for item in raw_X])
raw_X = normalize(raw_X)
print('X shape: ', raw_X.shape)
print('y shape: ', raw_y.shape)
imshow(raw_X[0])
# Out:
# Images loaded.
# Processing images..
# X shape:  (3485, 66, 200, 3)
# y shape:  (3485,)

# %%
shuffled_X, shuffled_y = shuffle_data(raw_X, raw_y)

# %%
train_X, train_y, val_X, val_y, test_X, test_y = split_data(shuffled_X, shuffled_y, 0.8, 0.1)

print('Train: ', len(train_X))
print('Validation: ', len(val_X))
print('Test: ', len(test_X))
print('Total: ', len(train_X) + len(val_X) + len(test_X))
# Out:
# Train:  2788
# Validation:  348
# Test:  349
# Total:  3485

# %%
# flip images to remove steering bias
X_flipped = np.array([np.fliplr(i) for i in train_X])
y_flipped = np.array([-i for i in train_y])
train_X = np.concatenate([train_X, X_flipped])
train_y = np.concatenate([train_y, y_flipped])
len(train_X)
# Out:
# 5576

# %%
from keras.models import Sequential
from keras.layers import Convolution2D, Activation, Dropout, Dense, Flatten
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Udacity SDC Model

# %%
model = Sequential()

#model.add(Lambda(lambda x: lamb(x), input_shape=(93, 160, 3)))

model.add(Convolution2D(24, (5,5), strides=(2,2), padding='valid', kernel_initializer='he_normal', input_shape=(66, 200, 3)))
model.add(Activation('elu'))
#model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Convolution2D(36, (5,5), strides=(2,2), padding='valid', kernel_initializer='he_normal'))
model.add(Activation('elu'))
#model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Convolution2D(48, (5,5), strides=(2,2), padding='valid', kernel_initializer='he_normal'))
model.add(Activation('elu'))
#model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Convolution2D(64, (3,3), strides=(1,1), padding='valid', kernel_initializer='he_normal'))
model.add(Activation('elu'))
#model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Convolution2D(64, (3,3), strides=(1,1), padding='valid', kernel_initializer='he_normal'))
model.add(Activation('elu'))
#model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Dropout(0.5))
model.add(Flatten())

model.add(Dense(100, kernel_initializer='he_normal'))
model.add(Activation('elu'))
model.add(Dense(50, kernel_initializer='he_normal'))
model.add(Activation('elu'))
model.add(Dense(10, kernel_initializer='he_normal'))
model.add(Activation('elu'))


model.add(Dense(1, kernel_initializer='he_normal'))

model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 31, 98, 24)        1824
# _________________________________________________________________
# activation_1 (Activation)    (None, 31, 98, 24)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 47, 36)        21636
# _________________________________________________________________
# activation_2 (Activation)    (None, 14, 47, 36)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 5, 22, 48)         43248
# _________________________________________________________________
# activation_3 (Activation)    (None, 5, 22, 48)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 3, 20, 64)         27712
# _________________________________________________________________
# activation_4 (Activation)    (None, 3, 20, 64)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 1, 18, 64)         36928
# _________________________________________________________________
# activation_5 (Activation)    (None, 1, 18, 64)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 18, 64)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               115300
# _________________________________________________________________
# activation_6 (Activation)    (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                5050
# _________________________________________________________________
# activation_7 (Activation)    (None, 50)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                510
# _________________________________________________________________
# activation_8 (Activation)    (None, 10)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 252,219
# Trainable params: 252,219
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train

# %%
from keras import callbacks
model_path = os.getcwd() + '/models/ud_loop.hdf5'
save_best = callbacks.ModelCheckpoint(model_path, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

early_stop = callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=0, mode='auto')

callbacks_list = [save_best, early_stop]

# %%
model.fit(train_X, train_y, batch_size=256, epochs=30, validation_data=(val_X, val_y), callbacks=callbacks_list)
# Out:
# Train on 5576 samples, validate on 348 samples
# Epoch 1/30
# 5376/5576 [===========================>..] - ETA: 0s - loss: 0.0021Epoch 00000: val_loss did not improve
# 5576/5576 [==============================] - 1s - loss: 0.0021 - val_loss: 0.0025
# Epoch 2/30
# 5376/5576 [===========================>..] - ETA: 0s - loss: 0.0021Epoch 00001: val_loss did not improve
# 5576/5576 [==============================] - 0s - loss: 0.0021 - val_loss: 0.0025
# Epoch 3/30
# 5376/5576 [===========================>..] - ETA: 0s - loss: 0.0021Epoch 00002: val_loss did not improve
# 5576/5576 [==============================] - 0s - loss: 0.0021 - val_loss: 0.0025
# Epoch 4/30
# 5376/5576 [===========================>..] - ETA: 0s - loss: 0.0021Epoch 00003: val_loss did not improve
# 5576/5576 [==============================] - 0s - loss: 0.0021 - val_loss: 0.0025
# Epoch 5/30
# 5376/5576 [===========================>..] - ETA: 0s - loss: 0.0021Epoch 00004: val_loss did not improve
# 5576/5576 [==============================] - 0s - loss: 0.0021 - val_loss: 0.0025
# Epoch 6/30
# 5376/5576 [===========================>..] - ETA: 0s - loss: 0.0020Epoch 00005: val_loss did not improve
# 5576/5576 [==============================] - 0s - loss: 0.0020 - val_loss: 0.0026
# Epoch 7/30
# 5376/5576 [===========================>..] - ETA: 0s - loss: 0.0020Epoch 00006: val_loss did not improve
# 5576/5576 [==============================] - 0s - loss: 0.0020 - val_loss: 0.0028
# Epoch 8/30
# 5376/5576 [===========================>..] - ETA: 0s - loss: 0.0022Epoch 00007: val_loss did not improve
# 5576/5576 [==============================] - 0s - loss: 0.0022 - val_loss: 0.0026
# Epoch 9/30
# 5376/5576 [===========================>..] - ETA: 0s - loss: 0.0021Epoch 00008: val_loss did not improve
# 5576/5576 [==============================] - 0s - loss: 0.0021 - val_loss: 0.0025
# Epoch 10/30
# 5376/5576 [===========================>..] - ETA: 0s - loss: 0.0020Epoch 00009: val_loss did not improve
# 5576/5576 [==============================] - 0s - loss: 0.0020 - val_loss: 0.0025
# Epoch 11/30
# 5376/5576 [===========================>..] - ETA: 0s - loss: 0.0019Epoch 00010: val_loss did not improve
# 5576/5576 [==============================] - 0s - loss: 0.0020 - val_loss: 0.0025
# Epoch 12/30
# 5376/5576 [===========================>..] - ETA: 0s - loss: 0.0020Epoch 00011: val_loss did not improve
# 5576/5576 [==============================] - 0s - loss: 0.0020 - val_loss: 0.0025
# Epoch 13/30
# 5376/5576 [===========================>..] - ETA: 0s - loss: 0.0020Epoch 00012: val_loss improved from 0.00245 to 0.00238, saving model to /home/exx/jtf/sdc_surfer/models/ud_loop.hdf5
# 5576/5576 [==============================] - 1s - loss: 0.0020 - val_loss: 0.0024
# Epoch 14/30
# 5376/5576 [===========================>..] - ETA: 0s - loss: 0.0020Epoch 00013: val_loss did not improve
# 5576/5576 [==============================] - 0s - loss: 0.0020 - val_loss: 0.0024
# Epoch 15/30
# 5376/5576 [===========================>..] - ETA: 0s - loss: 0.0019Epoch 00014: val_loss did not improve
# 5576/5576 [==============================] - 0s - loss: 0.0020 - val_loss: 0.0025
# Epoch 16/30
# 5376/5576 [===========================>..] - ETA: 0s - loss: 0.0020Epoch 00015: val_loss did not improve
# 5576/5576 [==============================] - 0s - loss: 0.0020 - val_loss: 0.0024
# Epoch 17/30
# 5376/5576 [===========================>..] - ETA: 0s - loss: 0.0020Epoch 00016: val_loss did not improve
# 5576/5576 [==============================] - 0s - loss: 0.0020 - val_loss: 0.0026
# Epoch 18/30
# 5376/5576 [===========================>..] - ETA: 0s - loss: 0.0020Epoch 00017: val_loss did not improve
# 5576/5576 [==============================] - 0s - loss: 0.0020 - val_loss: 0.0025
# Epoch 19/30
# 5376/5576 [===========================>..] - ETA: 0s - loss: 0.0019Epoch 00018: val_loss did not improve
# 5576/5576 [==============================] - 0s - loss: 0.0019 - val_loss: 0.0027

# %% [markdown]
# # Evaluate

# %%
import pandas as pd
from keras.models import load_model
#model_path = os.getcwd() + '/models/udacity_model.hdf5'
model = load_model(model_path)

# %% [markdown]
# # Test Data

# %%
pred_y = model.predict(test_X)
pred_y = pred_y.reshape((pred_y.shape[0],))
df = pd.DataFrame({'predicted':pred_y, 'actual':test_y})
ax = df.plot.scatter('predicted', 'actual')
ax2 = pd.DataFrame({'predicted':pred_y, 'actual':test_y}).plot()
ax2.set_ylabel('steering angle')

# %% [markdown]
# # Training Data

# %%
pred_y_2 = model.predict(train_X)
pred_y_2 = pred_y_2.reshape((pred_y_2.shape[0],))

ax = pd.DataFrame({'predicted':pred_y_2, 'actual':train_y}).plot()
ax.set_ylabel('steering angle')

# %%
print(model.predict(train_X[1:2]))
print(train_y[1])
# Out:
# [[-0.13246329]]
# -0.112

# %%
imshow(train_X[1])
